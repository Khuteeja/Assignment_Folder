# %%
import pandas as pd 
import matplotlib.pyplot as plt

data=[
['E001','M',34,123,'NORMAL',350],
['E002','F',40,114,'OVERWEIGHT',450],
['E003','F',37,135,'OBESITY',169],
['E004','M',30,139,'UNDERWEIGHT',189],
['E005','F',44,117,'UNDERWEIGHT ',183],
        ]
cols=['EMPID','GENDER','AGE','SALES','BMI','INCOME']
df=pd.DataFrame(data,columns=cols)

df.hist()

plt.show()

# %%
df.plot.bar()

plt.bar(df['AGE'],df['SALES'])
plt.xlabel('AGE')
plt.ylabel('SALES')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd 

data=[
['E001','M',34,123,'NORMAL',350],
['E002','F',40,114,'OVERWEIGHT',450],
['E003','F',37,135,'OBESITY',169],
['E004','M',30,139,'UNDERWEIGHT',189],
['E005','F',44,117,'UNDERWEIGHT ',183],
        ]
cols=['EMPID','GENDER','AGE','SALES','BMI','INCOME']
df=pd.DataFrame(data,columns=cols)

df.plot.box()
plt.boxplot(df['INCOME'])
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(50)
dataset=np.random.normal(100,25,200)#mean,standard deviation,number of data
print(len(dataset))
figure=plt.figure(figsize=(10,8))
plt.boxplot(dataset)
plt.show()
# Out:
# 200

# %%
plt.pie(df['AGE'],labels={'EMP1','EMP2','EMP3','EMP4','EMP5'}, autopct='%1.1f%%',shadow=True)
plt.show()

# %%
plt.scatter(df['INCOME'],df["AGE"])
plt.ylabel("AGES")
plt.xlabel("INCOME")
plt.
plt.show()
